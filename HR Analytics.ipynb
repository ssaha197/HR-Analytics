# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns',None)

# %%
general_data = pd.read_csv('C:\\Users\\user\\Desktop\\New folder\\Projects\\HR Analytics\\general_data.csv')

employee_survey_data = pd.read_csv('C:\\Users\\user\\Desktop\\New folder\\Projects\\HR Analytics\\employee_survey_data.csv')
manager_survey_data = pd.read_csv('C:\\Users\\user\\Desktop\\New folder\\Projects\\HR Analytics\\manager_survey_data.csv')

in_time_data = pd.read_csv('C:\\Users\\user\\Desktop\\New folder\\Projects\\HR Analytics\\in_time.csv')
out_time_data = pd.read_csv('C:\\Users\\user\\Desktop\\New folder\\Projects\\HR Analytics\\out_time.csv')

dictionary_data = pd.read_excel('C:\\Users\\user\\Desktop\\New folder\\Projects\\HR Analytics\\data_dictionary.xlsx')

# %% [raw]
# general_data
# employee_survey_data
# manager_survey_data
# in_time_data
# out_time_data
# dictionary_data

# %%
print(general_data.shape)
general_data.head()
# Out:
# (4410, 24)
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
# 2          4          Other              1           3    Male         4
# 3          5  Life Sciences              1           4    Male         3
# 4          1        Medical              1           5    Male         1
#
# ...

# %%
print(employee_survey_data.shape)
employee_survey_data.head()
# Out:
# (4410, 4)
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
print(manager_survey_data.shape)
manager_survey_data.head()
# Out:
# (4410, 3)
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
print(in_time_data.shape)
in_time_data.head()
# Out:
# (4410, 262)
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# ...

# %%
print(out_time_data.shape)
out_time_data.head()
# Out:
# (4410, 262)
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                  NaN  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# ...

# %%
dictionary_data.replace(np.nan,' ')
# Out:
#                     Variable  \
# 0                        Age
# 1                  Attrition
# 2             BusinessTravel
# 3                 Department
# 4           DistanceFromHome
# 5                  Education
# 6
# 7
# 8
# 9
# 10            EducationField
# 11             EmployeeCount
# 12            EmployeeNumber
# 13   EnvironmentSatisfaction
# 14
# 15
# 16
# 17                    Gender
# 18            JobInvolvement
# 19
# 20
# 21
# 22                  JobLevel
# 23                   JobRole
# 24           JobSatisfaction
# 25
# 26
# 27
# 28             MaritalStatus
# 29             MonthlyIncome
# 30        NumCompaniesWorked
# 31                    Over18
# 32         PercentSalaryHike
# 33         PerformanceRating
# 34
# 35
# 36
# 37  RelationshipSatisfaction
# 38
# 39
# 40
# 41             StandardHours
# 42          StockOptionLevel
# 43         TotalWorkingYears
# 44     TrainingTimesLastYear
# 45           WorkLifeBalance
# 46
# 47
# 48
# ...

# %%
general_data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
employee_survey_data.isnull().sum()
# Out:
# EmployeeID                  0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# dtype: int64

# %%
manager_survey_data.isnull().sum()
# Out:
# EmployeeID           0
# JobInvolvement       0
# PerformanceRating    0
# dtype: int64

# %%
in_time_data.isnull().sum()
# Out:
# Unnamed: 0       0
# 2015-01-01    4410
# 2015-01-02     209
# 2015-01-05     206
# 2015-01-06     228
#               ...
# 2015-12-25    4410
# 2015-12-28     234
# 2015-12-29     230
# 2015-12-30     265
# 2015-12-31     213
# Length: 262, dtype: int64

# %%
out_time_data.isnull().sum()
# Out:
# Unnamed: 0       0
# 2015-01-01    4410
# 2015-01-02     209
# 2015-01-05     206
# 2015-01-06     228
#               ...
# 2015-12-25    4410
# 2015-12-28     234
# 2015-12-29     230
# 2015-12-30     265
# 2015-12-31     213
# Length: 262, dtype: int64

# %% [markdown]
# ***

# %%
general_data.NumCompaniesWorked.value_counts()
# Out:
# 1.0    1558
# 0.0     586
# 3.0     474
# 2.0     438
# 4.0     415
# 7.0     222
# 6.0     208
# 5.0     187
# 9.0     156
# 8.0     147
# Name: NumCompaniesWorked, dtype: int64

# %%
general_data.TotalWorkingYears.value_counts().head()
# Out:
# 10.0    605
# 6.0     375
# 8.0     307
# 9.0     287
# 5.0     264
# Name: TotalWorkingYears, dtype: int64

# %%
general_data.TotalWorkingYears.mean()
# Out:
# 11.279936378095888

# %%
general_data['NumCompaniesWorked'].fillna(1.0, inplace = True)

general_data['TotalWorkingYears'].fillna(10.0, inplace = True)

# %%
employee_survey_data.EnvironmentSatisfaction.value_counts()
# Out:
# 3.0    1350
# 4.0    1334
# 2.0     856
# 1.0     845
# Name: EnvironmentSatisfaction, dtype: int64

# %%
employee_survey_data.EnvironmentSatisfaction.mean()
# Out:
# 2.7236031927023947

# %%
employee_survey_data.EnvironmentSatisfaction.median()
# Out:
# 3.0

# %%
employee_survey_data.JobSatisfaction.value_counts()
# Out:
# 4.0    1367
# 3.0    1323
# 1.0     860
# 2.0     840
# Name: JobSatisfaction, dtype: int64

# %%
employee_survey_data.JobSatisfaction.mean()
# Out:
# 2.728246013667426

# %%
employee_survey_data.JobSatisfaction.median()
# Out:
# 3.0

# %%
employee_survey_data.WorkLifeBalance.value_counts()
# Out:
# 3.0    2660
# 2.0    1019
# 4.0     454
# 1.0     239
# Name: WorkLifeBalance, dtype: int64

# %%
employee_survey_data.WorkLifeBalance.mean()
# Out:
# 2.7614364135407135

# %%
employee_survey_data.WorkLifeBalance.median()
# Out:
# 3.0

# %%
employee_survey_data['EnvironmentSatisfaction'].fillna(3.0, inplace = True)

employee_survey_data['JobSatisfaction'].fillna(3.0, inplace = True)

employee_survey_data['WorkLifeBalance'].fillna(3.0, inplace = True)

# %%
in_time_data.fillna(0, inplace = True)

out_time_data.fillna(0, inplace = True)

# %%
general_data.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
employee_survey_data.isnull().sum()
# Out:
# EmployeeID                 0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# dtype: int64

# %%
manager_survey_data.isnull().sum()
# Out:
# EmployeeID           0
# JobInvolvement       0
# PerformanceRating    0
# dtype: int64

# %%
in_time_data.isnull().sum()
# Out:
# Unnamed: 0    0
# 2015-01-01    0
# 2015-01-02    0
# 2015-01-05    0
# 2015-01-06    0
#              ..
# 2015-12-25    0
# 2015-12-28    0
# 2015-12-29    0
# 2015-12-30    0
# 2015-12-31    0
# Length: 262, dtype: int64

# %%
out_time_data.isnull().sum()
# Out:
# Unnamed: 0    0
# 2015-01-01    0
# 2015-01-02    0
# 2015-01-05    0
# 2015-01-06    0
#              ..
# 2015-12-25    0
# 2015-12-28    0
# 2015-12-29    0
# 2015-12-30    0
# 2015-12-31    0
# Length: 262, dtype: int64

# %% [markdown]
# ***

# %%
in_time_data.iloc[:, 1:] = in_time_data.iloc[:, 1:].apply(pd.to_datetime, errors = 'coerce')
out_time_data.iloc[:, 1:] = out_time_data.iloc[:, 1:].apply(pd.to_datetime, errors = 'coerce')

#coerce : in case of error during conversion, place NaN or NaT

# %%
total_time_data = in_time_data.append(out_time_data)

# %%
total_time_data = total_time_data.diff(periods = 4410)
total_time_data = total_time_data.iloc[4410:]

total_time_data.reset_index(inplace = True)
total_time_data.head()
# Out:
#    index  Unnamed: 0 2015-01-01      2015-01-02      2015-01-05  \
# 0      0         0.0     0 days 0 days 07:12:30 0 days 07:11:23
# 1      1         0.0     0 days 0 days 08:06:33 0 days 07:27:17
# 2      2         0.0     0 days 0 days 06:41:33 0 days 07:15:56
# 3      3         0.0     0 days 0 days 07:20:18 0 days 07:17:31
# 4      4         0.0     0 days 0 days 08:03:20 0 days 07:59:17
#
#        2015-01-06      2015-01-07      2015-01-08      2015-01-09  \
# 0 0 days 07:24:39 0 days 07:00:24 0 days 07:17:23 0 days 07:29:04
# 1 0 days 00:00:00 0 days 07:23:49 0 days 07:25:00 0 days 07:09:03
# 2 0 days 06:24:19 0 days 06:45:54 0 days 07:20:42 0 days 06:51:41
# 3 0 days 06:56:35 0 days 06:55:10 0 days 06:51:03 0 days 07:11:35
# 4 0 days 07:40:57 0 days 07:48:22 0 days 07:39:44 0 days 07:43:18
#
#        2015-01-12      2015-01-13 2015-01-14      2015-01-15      2015-01-16  \
# 0 0 days 07:15:46 0 days 07:49:52     0 days 0 days 07:20:49 0 days 07:16:03
# ...

# %%
total_time_data.drop(columns = ['index','Unnamed: 0'], axis = 1, inplace = True)
total_time_data.head()
# Out:
#   2015-01-01      2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0     0 days 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1     0 days 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2     0 days 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3     0 days 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4     0 days 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
#
#        2015-01-08      2015-01-09      2015-01-12      2015-01-13 2015-01-14  \
# 0 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46 0 days 07:49:52     0 days
# 1 0 days 07:25:00 0 days 07:09:03 0 days 07:36:41 0 days 07:16:44     0 days
# 2 0 days 07:20:42 0 days 06:51:41 0 days 07:25:07 0 days 06:59:59     0 days
# 3 0 days 06:51:03 0 days 07:11:35 0 days 06:59:55 0 days 07:18:23     0 days
# 4 0 days 07:39:44 0 days 07:43:18 0 days 08:21:54 0 days 08:15:26     0 days
#
# ...

# %%
# remove all holidays

total_time_data.drop(['2015-01-01','2015-01-14','2015-01-26','2015-03-05','2015-05-01','2015-07-17','2015-09-17','2015-10-02','2015-11-09','2015-11-10','2015-11-11','2015-12-25'], axis = 1, inplace = True)

# %%
total_time_data['mean_time'] = total_time_data.mean(axis = 1)

# %%
total_time_data.head()
# Out:
#        2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
#
#        2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# 0 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46 0 days 07:49:52
# 1 0 days 07:25:00 0 days 07:09:03 0 days 07:36:41 0 days 07:16:44
# 2 0 days 07:20:42 0 days 06:51:41 0 days 07:25:07 0 days 06:59:59
# 3 0 days 06:51:03 0 days 07:11:35 0 days 06:59:55 0 days 07:18:23
# 4 0 days 07:39:44 0 days 07:43:18 0 days 08:21:54 0 days 08:15:26
#
#        2015-01-15      2015-01-16      2015-01-19      2015-01-20  \
# 0 0 days 07:20:49 0 days 07:16:03 0 days 00:00:00 0 days 06:46:33
# ...

# %%
total_time_data.shape
# Out:
# (4410, 250)

# %%
total_time_data.iloc[0,0]
# Out:
# Timedelta('0 days 07:12:30')

# %%
total_time_data.iloc[0,249]
# Out:
# Timedelta('0 days 06:52:12.823293172')

# %%
total_time_data.mean_time = total_time_data.mean_time.apply(lambda x : int(str(x).split(' ')[2].split(':')[0]) + int((str(x).split(' ')[2].split(':')[1]))/60 + float((str(x).split(' ')[2].split(':')[2]))/3600)

# %%
total_time_data.reset_index(inplace = True)

# %%
total_time_data.head()
# Out:
#    index      2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0      0 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1      1 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2      2 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3      3 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4      4 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
#
#        2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# 0 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46 0 days 07:49:52
# 1 0 days 07:25:00 0 days 07:09:03 0 days 07:36:41 0 days 07:16:44
# 2 0 days 07:20:42 0 days 06:51:41 0 days 07:25:07 0 days 06:59:59
# 3 0 days 06:51:03 0 days 07:11:35 0 days 06:59:55 0 days 07:18:23
# 4 0 days 07:39:44 0 days 07:43:18 0 days 08:21:54 0 days 08:15:26
#
#        2015-01-15      2015-01-16      2015-01-19      2015-01-20  \
# ...

# %%
total_time_data = total_time_data.rename(columns = {'index': 'EmployeeID'})
total_time_data = total_time_data.rename(columns = {'mean_time': 'mean_time_hrs'})

# %%
total_time_data = total_time_data.drop((total_time_data.columns[1 : -1]), axis = 1)

# %%
total_time_data.head()
# Out:
#    EmployeeID  mean_time_hrs
# 0           0       6.870229
# 1           1       7.315971
# 2           2       6.816081
# 3           3       6.789215
# 4           4       7.877561

# %% [markdown]
# ***

# %%
data = pd.merge(general_data, employee_survey_data, on = 'EmployeeID', how = 'inner')

data = pd.merge(data, manager_survey_data, on = 'EmployeeID', how = 'inner')

data = pd.merge(data, total_time_data, on = 'EmployeeID', how = 'inner')

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences              1           1  Female         1
# 1          1  Life Sciences              1           2  Female         1
# 2          4          Other              1           3    Male         4
# 3          5  Life Sciences              1           4    Male         3
# 4          1        Medical              1           5    Male         1
#
# ...

# %%
data.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# JobInvolvement             0
# PerformanceRating          0
# mean_time_hrs              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4409 entries, 0 to 4408
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4409 non-null   int64
#  1   Attrition                4409 non-null   object
#  2   BusinessTravel           4409 non-null   object
#  3   Department               4409 non-null   object
#  4   DistanceFromHome         4409 non-null   int64
#  5   Education                4409 non-null   int64
#  6   EducationField           4409 non-null   object
#  7   EmployeeCount            4409 non-null   int64
#  8   EmployeeID               4409 non-null   int64
#  9   Gender                   4409 non-null   object
#  10  JobLevel                 4409 non-null   int64
#  11  JobRole                  4409 non-null   object
#  12  MaritalStatus            4409 non-null   object
#  13  MonthlyIncome            4409 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4409.000000       4409.000000  4409.000000         4409.0  4409.000000
# mean     36.923112          9.188251     2.912905            1.0  2205.000000
# std       9.134220          8.100992     1.024048            0.0  1272.912998
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.000000
# 50%      36.000000          7.000000     3.000000            1.0  2205.000000
# 75%      43.000000         14.000000     4.000000            1.0  3307.000000
# max      60.000000         29.000000     5.000000            1.0  4409.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4409.000000    4409.000000         4409.000000        4409.000000
# mean      2.063960   65031.660240            2.688138          15.210252
# ...

# %% [raw]
# 'EmployeeCount' & 'StandardHours' have 0 standard deviation (std) which means same values is present in each record

# %%
obj_cols = data.select_dtypes(include = ['object']).columns

for i in obj_cols:
    unique_values = len(data[i].value_counts())
    if unique_values == 1:
        print(i, 'has only 1 unique value')
# Out:
# Over18 has only 1 unique value

# %%
data.drop(['EmployeeCount','StandardHours','Over18'], axis = 1, inplace = True)

# %% [markdown]
# ***

# %%
dataset = data.copy()

# %%
dataset.Age = pd.cut(dataset.Age, range(10, 70, 10))

# %%
def make_plot(feature_name, x_ticks = 'not_needed'):
    ax = sns.countplot(x = feature_name, hue = 'Attrition', data = dataset, palette = 'magma')
    
    if x_ticks != 'not_needed':
        ticks_index = [i for i in range(len(x_ticks))]
        ax.set(xticks = ticks_index, xticklabels = x_ticks)
        
    plt.xlabel(feature_name)
    plt.ylabel('Employee Count')
    plt.title('{} vs Attrition'.format(feature_name))
    plt.legend()
    
    get_bars = ax.patches
    half_bar_length = int(len(get_bars)/2)
    bar_left = get_bars[:half_bar_length]
    bar_right = get_bars[half_bar_length:]
    
    for L, R in zip(bar_left, bar_right):
        left_height = L.get_height()
        right_height = R.get_height()
        length_total = left_height + right_height
        
        ax.text(L.get_x() + L.get_width()/2., left_height + 30, '{0:.0%}'.format(left_height/length_total), ha = 'center')
        ax.text(R.get_x() + R.get_width()/2., right_height + 30, '{0:.0%}'.format(right_height/length_total), ha = 'center')

# %%
make_plot('Age')

# %%
make_plot('BusinessTravel')

# %%
make_plot('Department')

# %%
make_plot('Education',['Balow College','College','Bachelor','Master','Doctor'])

# %%
make_plot('EducationField')

# %%
make_plot('Gender')

# %%
make_plot('JobLevel')

# %%
make_plot('JobRole')
plt.xticks(rotation = 45)
plt.show()

# %%
make_plot('MaritalStatus')

# %%
make_plot('NumCompaniesWorked')

# %%
make_plot('StockOptionLevel')

# %%
make_plot('EnvironmentSatisfaction', ['Low', 'Medium', 'High', 'Very High'])

# %%
make_plot('JobSatisfaction', ['Low', 'Medium', 'High', 'Very High'])

# %%
make_plot('WorkLifeBalance', ['Bad', 'Good', 'Better', 'Best'])

# %%
make_plot('JobInvolvement', ['Low', 'Medium', 'High', 'Very High'])

# %%
make_plot('PerformanceRating')

# %%
continuous_features = ['DistanceFromHome', 'MonthlyIncome', 
                       'PercentSalaryHike', 'TotalWorkingYears',
                       'TrainingTimesLastYear', 'YearsAtCompany', 
                       'YearsSinceLastPromotion', 'YearsWithCurrManager',
                       'mean_time_hrs']

# %%
fig, ax = plt.subplots(3,3, figsize = (18, 10))
index = 0
for i in range(3):
    for j in range(3):
        ax[i][j].set_title('Attrition vs %s' % (continuous_features[index]), fontweight = 'bold')
        
        sns.kdeplot(data[data['Attrition'] == 'Yes'][continuous_features[index]], label = 'Attrition = Yes',shade = True ,ax = ax[i][j])
        sns.kdeplot(data[data['Attrition'] == 'No'][continuous_features[index]], label = 'Attrition = No',shade = True ,ax = ax[i][j])
        ax[i][j].legend()
        
        index += 1
        
plt.tight_layout()
plt.show()

# %%
ax = sns.countplot(dataset.Attrition)

get_bars = ax.patches
half_bar_length = int(len(get_bars)/2)
bar_left = get_bars[:half_bar_length]
bar_right = get_bars[half_bar_length:]
    
for L, R in zip(bar_left, bar_right):
    left_height = L.get_height()
    right_height = R.get_height()
    length_total = left_height + right_height
        
    ax.text(L.get_x() + L.get_width()/2., left_height + 30, '{0:.0%}'.format(left_height/length_total), ha = 'center')
    ax.text(R.get_x() + R.get_width()/2., right_height + 30, '{0:.0%}'.format(right_height/length_total), ha = 'center')

# %% [markdown]
# ***

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeID  Gender  JobLevel  \
# 0          2  Life Sciences           1  Female         1
# 1          1  Life Sciences           2  Female         1
# 2          4          Other           3    Male         4
# 3          5  Life Sciences           4    Male         3
# 4          1        Medical           5    Male         1
#
#                      JobRole MaritalStatus  MonthlyIncome  NumCompaniesWorked  \
# ...

# %%
one_hot_var = ['BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus']

for i in one_hot_var:
    encode = pd.get_dummies(data[i], prefix = i, prefix_sep = '_', drop_first = True)
    
    data = data.join(encode)
    
    data.drop(i, axis = 1, inplace = True)

# %%
data.Attrition = data.Attrition.apply(lambda x: 1 if x == 'Yes' else 0)

data.Gender = data.Gender.apply(lambda x: 1 if x == 'Male' else 0)

# %%
data.head()
# Out:
#    Age  Attrition  DistanceFromHome  Education  EmployeeID  Gender  JobLevel  \
# 0   51          0                 6          2           1       0         1
# 1   31          1                10          1           2       0         1
# 2   32          0                17          4           3       1         4
# 3   38          0                 2          5           4       1         3
# 4   32          0                10          1           5       1         1
#
#    MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# 0         131160                 1.0                 11                 0
# 1          41890                 0.0                 23                 1
# 2         193280                 1.0                 15                 3
# 3          83210                 3.0                 11                 3
# 4          23420                 4.0                 12                 2
#
# ...

# %%
x = data.drop('Attrition', axis = 1)
y = data['Attrition']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, stratify = y, random_state = 19)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train[x_train.columns[:21]] = sc.fit_transform(x_train[x_train.columns[:21]])
x_test[x_train.columns[:21]] = sc.transform(x_test[x_train.columns[:21]])

#using standard scalar only on one_hot_var changed columns

# %%
data_corr = x_train.copy()

plt.figure(figsize = (20,15))
sns.heatmap(data_corr.corr(),cbar = True)
plt.show()

# %%
data_corr['Attribution'] = y_train

# %%
plt.figure(figsize = (20,15))
data_corr.corr()['Attribution'].sort_values(ascending = False)[1:].plot(kind = 'bar')
plt.title('Features collinearity with the target')
plt.ylabel('Collinearity')
plt.show()

# %%
data_corr = data_corr.corr()

for i in range(data_corr.shape[0]):
    for j in range(data_corr.shape[1]):
        if(abs(data_corr.iloc[i, j]) > 0.8) & (abs(data_corr.iloc[i, j]) != 1):
            print('Correlation = ',round(data_corr.iloc[i, j],3), data_corr.columns[j],' & ',data_corr.index[i])
# Out:
# Correlation =  -0.905 Department_Sales  &  Department_Research & Development
# Correlation =  -0.905 Department_Research & Development  &  Department_Sales

# %%
# Department_Sales  &  Department_Research & Development are highly correlated
# so, dropping one of them

x_train.drop('Department_Sales', axis = 1, inplace = True)
x_test.drop('Department_Sales', axis = 1, inplace = True)

# %%
x_train.head()
# Out:
#            Age  DistanceFromHome  Education  EmployeeID    Gender  JobLevel  \
# 112  -1.748177          0.081906  -0.898302   -1.646140  0.818350 -0.966572
# 1158  0.110596          1.180658   0.080211   -0.824902 -1.221971 -0.047536
# 4154  0.001257         -0.894762   0.080211    1.527326  0.818350 -0.966572
# 3412 -0.764120         -0.650595   0.080211    0.944765 -1.221971  2.709571
# 1081 -1.638837          0.814407  -0.898302   -0.885357 -1.221971 -0.047536
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# 112       -0.232071           -0.681421          -0.878402          0.253461
# 1158       0.096938           -1.074988           0.498683         -0.926738
# 4154      -0.172763            1.286414           1.049517         -0.926738
# 3412      -0.181854           -1.074988          -0.878402          0.253461
# 1081      -0.620388           -0.681421           1.049517          2.613857
#
# ...

# %% [markdown]
# ***

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9728014505893019

# %%
f1_score(y_test, y_pred)
# Out:
# 0.9137931034482758

# %%
precision_score(y_test, y_pred)
# Out:
# 0.9352941176470588

# %%
recall_score(y_test, y_pred)
# Out:
# 0.8932584269662921

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[914  11]
#  [ 19 159]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       925
#            1       0.94      0.89      0.91       178
#
#     accuracy                           0.97      1103
#    macro avg       0.96      0.94      0.95      1103
# weighted avg       0.97      0.97      0.97      1103
